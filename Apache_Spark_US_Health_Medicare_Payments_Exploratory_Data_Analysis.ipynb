# %% [markdown]
# # US Health Medicare Payments Exploratory Data Analysis with Spark
#
# ### Examine Four Years of US Health Medicare Payments Data Using Spark

# %%
#Let's mount Google Drive So We can Retrieve the Data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#There is Five Files of Health Payments Data From 2014 to 2017. Source  XXXXXXX
# !ls "/content/gdrive/My Drive/Health Data/"
# Out:
# PGYR14_P011819.ZIP  PGYR15_P011819.ZIP	PGYR16_P011819.ZIP  PGYR17_P011819.ZIP

# %%
#Unzip the files
#!rm -r *
# !unzip -qq "/content/gdrive/My Drive/Health Data/PGYR14_P011819.ZIP"
# !unzip -qq "/content/gdrive/My Drive/Health Data/PGYR15_P011819.ZIP"
# !unzip -qq "/content/gdrive/My Drive/Health Data/PGYR16_P011819.ZIP"
# !unzip -qq "/content/gdrive/My Drive/Health Data/PGYR17_P011819.ZIP"
# Out:
# replace OP_DTL_GNRL_PGYR2014_P01182019.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# replace OP_DTL_GNRL_PGYR2015_P01182019.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# replace OP_DTL_GNRL_PGYR2016_P01182019.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# replace OP_DTL_GNRL_PGYR2017_P01182019.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
#Examine the Readme File OP_PGYR2013_README_P01182019...

# !cat OP_PGYR2014_README_P01182019.txt

#Each ZIP file contains 4 CSV Data Files. We are interested in the payments file...OP_DTL_GNRL_PGYR2013_P01182019.csv
# Out:
# Filename: OP_PGYR2014_README_P01182019.txt
# Version: 1.0
# Date: January 2019
#
# 1. Program Year 2014 Data Files
#
# This data set includes records submitted for the 2014 program year that have been matched with total confidence to a particular covered recipient (i.e., physician or teaching hospital) and displays information about that recipient. This data set includes the most recent attested-to data for Program Year 2014 as of December 31, 2018.
#
# The data set contained in the comma-separated values (CSV) file includes only the data that is eligible for publication. Consult the Open Payments Methodology and Data Dictionary Document for an explanation of the criteria that the Centers for Medicare and Medicaid Services (CMS) used to determine what data to publish. This document can be found on the Resources page of the Open Payments website (https://www.cms.gov/OpenPayments/About/Resources.html). The Methodology and Data Dictionary Document also includes information on the data collection and reporting methodology, data fields included in the files, and any notes or special considerations that users should be aware of.
#
# Each record in the General Payment, Research Payment, and Ownership/Investment files includes a Change Type indicator field. The Change Type value of NEW indicates that the record is newly reported by the reporting entity since the last publication and is being published for the first time. The Change Type value of ADD indicates that the record is not new in the system but, due to the record not being eligible for publication until the current publication cycle, is being published for the first time. The Change Type value of CHANGED indicates that the record was previously published but has been modified since its last publication. A record whose only change since the last publication is a change to its dispute status is categorized as a changed record. The Change Type value of UNCHANGED indicates that the record was published during the last publication cycle and is being republished without change in the current publication.
#
# Each record in the Removed and Deleted Records file includes a Change Type indicator field as well. The Change Type value of DELETED indicates the previously published record was deleted from the Open Payments system by the reporting entity. The Change Type value of REMOVED indicates that the previously published record was removed from the current publication as a result of the reporting entity making updates to the record which made the record ineligible for publication.
#
# 2. Considerations for using the CSV Files
#
# Microsoft Excel removes leading zeroes from data fields in CSV files. Certain fields in these data sets may have leading zeroes. These zeroes will be missing when viewing the information within Microsoft Excel.
#
# Additionally, the latest versions of Microsoft Excel cannot display data sets with more than 1,048,576 rows. Some of these CSV files may exceed that limit. Displaying the data in its entirety may require the use of spreadsheet programs capable of handling very large numbers of records.
#
# 3. Details about the Datasets Included in this OP_DTL_PGYR2014_P01182019.zip file
#
# This compressed (.zip) file contains four (4) comma-separated values (CSV) files that use commas as delimiters and one (1) README.txt file. Descriptions of each file contained in this compressed (.zip) file are provided below.
#
# File #1 - OP_DTL_GNRL_PGYR2014_P01182019.csv:
# This file contains the data set of General Payments reported for the 2014 program year. General Payments are defined as payments or other transfers of value made to a covered recipient (physician or teaching hospital) that are not made in connection with a research agreement or research protocol.
#
# File #2 - OP_DTL_RSRCH_PGYR2014_P01182019.csv:
# This file contains the data set of Research Payments reported for the 2014 program year. Research Payments are defined as payments or other transfers of value made in connection with a research agreement or research protocol.
#
# File #3 - OP_DTL_OWNRSHP_PGYR2014_P01182019.csv:
# This file contains the data set of Ownership and Investment Interest Information reported for the 2014 program year. Ownership and Investment Interest Information is defined as information about the value of ownership or investment interests that a physician or an immediate family member of a physician held in an applicable manufacturer or applicable group purchasing organization (GPO).
#
# File #4 - OP_REMOVED_DELETED_PGYR2014_P01182019.csv:
# This file contains the data set of records that were published in a previous publication of the program year data but have been deleted or removed from the current publication. Deleted records refer to records that were published in the last publication and have since been deleted by the applicable manufacturer or applicable GPO. Removed records refer to records that were published in the last publication and have since become ineligible for publication. Ineligible records may include records that were previously published and have since been edited by an applicable manufacturer or applicable GPO without re-attestation. It may also include records that were previously published and the applicable manufacturer or applicable GPO requested a delay in publication. The only identifying information provided for records in this file is the "Open Payments Record ID." This ID number allows users to determine whether records previously published have been removed from this publication.
#
# Also available is a supplementary file that displays information for physicians including principal investigators indicated as recipients of payments. This supplementary file can be found in a separate zip file:
#
# OP_PH_PRFL_SPLMTL_P01182019.zip:
# The physician profile information included in the data sets is submitted by the reporting entity. In contrast, the physician information included in the supplementary file can be derived from different sources including the National Plan and Provider Enumeration System (NPPES) and the Provider Enrollment, Chain and Ownership System (PECOS). As a result, the data in these sources may differ slightly. When searching for physicians using the Open Payments search tool on https://openpaymentsdata.cms.gov, use the physician profile information as listed in the supplementary file.

# %%
# !ls
# Out:
# gdrive
# OP_DTL_GNRL_PGYR2014_P01182019.csv
# OP_DTL_GNRL_PGYR2015_P01182019.csv
# OP_DTL_GNRL_PGYR2016_P01182019.csv
# OP_DTL_GNRL_PGYR2017_P01182019.csv
# OP_DTL_OWNRSHP_PGYR2014_P01182019.csv
# OP_DTL_OWNRSHP_PGYR2015_P01182019.csv
# OP_DTL_OWNRSHP_PGYR2016_P01182019.csv
# OP_DTL_OWNRSHP_PGYR2017_P01182019.csv
# OP_DTL_RSRCH_PGYR2014_P01182019.csv
# OP_DTL_RSRCH_PGYR2015_P01182019.csv
# OP_DTL_RSRCH_PGYR2016_P01182019.csv
# OP_DTL_RSRCH_PGYR2017_P01182019.csv
# OP_PGYR2014_README_P01182019.txt
# OP_PGYR2015_README_P01182019.txt
# OP_PGYR2016_README_P01182019.txt
# OP_PGYR2017_README_P01182019.txt
# OP_REMOVED_DELETED_PGYR2014_P01182019.csv
# OP_REMOVED_DELETED_PGYR2015_P01182019.csv
# OP_REMOVED_DELETED_PGYR2016_P01182019.csv
# OP_REMOVED_DELETED_PGYR2017_P01182019.csv
# sample_data
# spark-2.4.3-bin-hadoop2.7
# spark-2.4.3-bin-hadoop2.7.tgz

# %% [markdown]
# # **Install and Load Up Spark**

# %%
#Install Latest Version of Spark As of Current Data. 2.4.3

# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://www-eu.apache.org/dist/spark/spark-2.4.3/spark-2.4.3-bin-hadoop2.7.tgz
# !tar xf spark-2.4.3-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.3-bin-hadoop2.7"

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
#Import the csv files for 2014 to 2017, examine and aggregate into one file. 


df2014 = spark.read.format("csv").option("inferSchema", True).option("header", True).load('OP_DTL_GNRL_PGYR2014_P01182019.csv')
df2015 = spark.read.format("csv").option("inferSchema", True).option("header", True).load('OP_DTL_GNRL_PGYR2015_P01182019.csv')
df2016 = spark.read.format("csv").option("inferSchema", True).option("header", True).load('OP_DTL_GNRL_PGYR2016_P01182019.csv')
df2017 = spark.read.format("csv").option("inferSchema", True).option("header", True).load('OP_DTL_GNRL_PGYR2017_P01182019.csv')

# %%
#Examine the data to see if fields match up.

df2014.limit(5).toPandas()

# %%
df2017.limit(5).toPandas()
# Out:
#   Change_Type  ... Payment_Publication_Date
# 0   UNCHANGED  ...               01/18/2019
# 1   UNCHANGED  ...               01/18/2019
# 2   UNCHANGED  ...               01/18/2019
# 3   UNCHANGED  ...               01/18/2019
# 4   UNCHANGED  ...               01/18/2019
#
# [5 rows x 75 columns]

# %% [markdown]
# **ANALYSIS**
# Examining the tables above (only 2014 and 2017 show for simplicity), it looks like new fields were added for year 2016 and 2017. Most of the fields have the same name across the files. Key fields such as Physician information and Payment information looks exactly the same across the files. We will drop fields that do not match the 2014 data and aggregate the data into one file.

# %%
#Lets determine which fields are in all files and drop fields that are in not 2013.
col2014 = df2014.columns
colkeep = [column for column in df2017.columns if column in col2014]


df2014 = df2014.select(colkeep)
df2015 = df2015.select(colkeep)
df2016 = df2016.select(colkeep)
df2017 = df2017.select(colkeep)

print("Fields in respectove files...", len(df2014.columns), len(df2015.columns), len(df2016.columns), len(df2017.columns),
# Out:
# (49, 49, 49, 49)

# %% [markdown]
# **ANALYSIS**
# There are 49 common fields among the files. Below we ensure that the record number matches the total of the indiviuals files. Then we will combine the four dataframes into one df and save it as a parquet file.

# %%
#total number of records
print('Total Number of Records....", df2014.count() + df2015.count() + df2016.count() + df2017.count())
# Out:
# 43999854

# %%
#Spark doesn't have a function to append multiple dataframes. So we have to use a workaround.

from functools import reduce
from pyspark.sql import DataFrame

def unionAll(*dfa):
    return reduce(DataFrame.unionAll, dfa)

df = unionAll(df2014, df2015, df2016, df2017)
df.cache()
# Out:
# DataFrame[Change_Type: string, Covered_Recipient_Type: string, Teaching_Hospital_CCN: int, Teaching_Hospital_ID: int, Teaching_Hospital_Name: string, Physician_Profile_ID: int, Physician_First_Name: string, Physician_Middle_Name: string, Physician_Last_Name: string, Physician_Name_Suffix: string, Recipient_Primary_Business_Street_Address_Line1: string, Recipient_Primary_Business_Street_Address_Line2: string, Recipient_City: string, Recipient_State: string, Recipient_Zip_Code: string, Recipient_Country: string, Recipient_Province: string, Recipient_Postal_Code: string, Physician_Primary_Type: string, Physician_Specialty: string, Physician_License_State_code1: string, Physician_License_State_code2: string, Physician_License_State_code3: string, Physician_License_State_code4: string, Physician_License_State_code5: string, Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name: string, Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID: string, Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name: string, Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State: string, Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country: string, Total_Amount_of_Payment_USDollars: string, Date_of_Payment: string, Number_of_Payments_Included_in_Total_Amount: string, Form_of_Payment_or_Transfer_of_Value: string, Nature_of_Payment_or_Transfer_of_Value: string, City_of_Travel: string, State_of_Travel: string, Country_of_Travel: string, Physician_Ownership_Indicator: string, Third_Party_Payment_Recipient_Indicator: string, Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value: string, Charity_Indicator: string, Third_Party_Equals_Covered_Recipient_Indicator: string, Contextual_Information: string, Delay_in_Publication_Indicator: string, Record_ID: string, Dispute_Status_for_Publication: string, Program_Year: string, Payment_Publication_Date: string]

# %%
print('Number of records in the unified file....', df.count()) #The number of records match the aggregate of the number of records in the individual files.
# Out:
# 43999854

# %%
#Lets looks at the combined dataframe
df.limit(5).toPandas()
# Out:
#   Change_Type  ... Payment_Publication_Date
# 0   UNCHANGED  ...               01/18/2019
# 1   UNCHANGED  ...               01/18/2019
# 2   UNCHANGED  ...               01/18/2019
# 3   UNCHANGED  ...               01/18/2019
# 4   UNCHANGED  ...               01/18/2019
#
# [5 rows x 49 columns]

# %%
#Convert numerical fields from string to appropriate datatype
#numerical: Total_Amount_of_Payment_USDollars, Total_Amount_of_Payment_USDollars

df = df.withColumn('Total_Amount_of_Payment_USDollars', df.Total_Amount_of_Payment_USDollars.cast('Decimal'))
df = df.withColumn('Number_of_Payments_Included_in_Total_Amount', df.Number_of_Payments_Included_in_Total_Amount.cast('Decimal'))

#Change Payment data to Date Type
from pyspark.sql import functions as Func
df = df.withColumn('Date_of_Payment', Func.to_date('Date_of_Payment', 'MM/dd/yyyy'))

# %%
#Save to Parquet

#df.write.parquet("/content/gdrive/My Drive/Health Data/Health14to17.parquet")

# %% [markdown]
# #Exploratory Data Analysis on 4 Million Plus Records!

# %%
df = spark.read.parquet("/content/gdrive/My Drive/Health Data/Health14to17.parquet")

# %%
#Look at the distribution of Total Payments (2013 to 2017)
import pandas as pd
df.describe('Total_Amount_of_Payment_USDollars').toPandas().style.hide_index()\
.set_properties(**{'background-color': 'lightgrey', 'color': 'Black','border-color': 'white', "text-align" : "right"})
# Out:
# <style  type="text/css" >
#     #T_ede0c292_8d36_11e9_9a95_0242ac1c0002row0_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_ede0c292_8d36_11e9_9a95_0242ac1c0002row0_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_ede0c292_8d36_11e9_9a95_0242ac1c0002row1_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_ede0c292_8d36_11e9_9a95_0242ac1c0002row1_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_ede0c292_8d36_11e9_9a95_0242ac1c0002row2_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_ede0c292_8d36_11e9_9a95_0242ac1c0002row2_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_ede0c292_8d36_11e9_9a95_0242ac1c0002row3_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_ede0c292_8d36_11e9_9a95_0242ac1c0002row3_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_ede0c292_8d36_11e9_9a95_0242ac1c0002row4_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_ede0c292_8d36_11e9_9a95_0242ac1c0002row4_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }</style><table id="T_ede0c292_8d36_11e9_9a95_0242ac1c0002" ><thead>    <tr>        <th class="col_heading level0 col0" >summary</th>        <th class="col_heading level0 col1" >Total_Amount_of_Payment_USDollars</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ede0c292_8d36_11e9_9a95_0242ac1c0002row0_col0" class="data row0 col0" >count</td>
#                         <td id="T_ede0c292_8d36_11e9_9a95_0242ac1c0002row0_col1" class="data row0 col1" >43999839</td>
#             </tr>
#             <tr>
#                                 <td id="T_ede0c292_8d36_11e9_9a95_0242ac1c0002row1_col0" class="data row1 col0" >mean</td>
#                         <td id="T_ede0c292_8d36_11e9_9a95_0242ac1c0002row1_col1" class="data row1 col1" >249.9117</td>
#             </tr>
#             <tr>
#                                 <td id="T_ede0c292_8d36_11e9_9a95_0242ac1c0002row2_col0" class="data row2 col0" >stddev</td>
#                         <td id="T_ede0c292_8d36_11e9_9a95_0242ac1c0002row2_col1" class="data row2 col1" >21290.3431381885</td>
#             </tr>
#             <tr>
#                                 <td id="T_ede0c292_8d36_11e9_9a95_0242ac1c0002row3_col0" class="data row3 col0" >min</td>
#                         <td id="T_ede0c292_8d36_11e9_9a95_0242ac1c0002row3_col1" class="data row3 col1" >0</td>
#             </tr>
#             <tr>
#                                 <td id="T_ede0c292_8d36_11e9_9a95_0242ac1c0002row4_col0" class="data row4 col0" >max</td>
#                         <td id="T_ede0c292_8d36_11e9_9a95_0242ac1c0002row4_col1" class="data row4 col1" >41414329</td>
#             </tr>
#     </tbody></table>

# %%
#Total Payments By Program Year
df.groupby('Program_year').sum('Total_Amount_of_Payment_USDollars').orderBy('Program_year', ascending = False)\
.toPandas().style.format({'sum(Total_Amount_of_Payment_USDollars)':'${0:,.0f}'}).hide_index()\
.set_properties(**{'background-color': 'lightgrey', 'color': 'Black','border-color': 'white', "text-align" : "right"})
# Out:
# <style  type="text/css" >
#     #T_d98ba154_8d36_11e9_9a95_0242ac1c0002row0_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_d98ba154_8d36_11e9_9a95_0242ac1c0002row0_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_d98ba154_8d36_11e9_9a95_0242ac1c0002row1_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_d98ba154_8d36_11e9_9a95_0242ac1c0002row1_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_d98ba154_8d36_11e9_9a95_0242ac1c0002row2_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_d98ba154_8d36_11e9_9a95_0242ac1c0002row2_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_d98ba154_8d36_11e9_9a95_0242ac1c0002row3_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_d98ba154_8d36_11e9_9a95_0242ac1c0002row3_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_d98ba154_8d36_11e9_9a95_0242ac1c0002row4_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_d98ba154_8d36_11e9_9a95_0242ac1c0002row4_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_d98ba154_8d36_11e9_9a95_0242ac1c0002row5_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_d98ba154_8d36_11e9_9a95_0242ac1c0002row5_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }</style><table id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002" ><thead>    <tr>        <th class="col_heading level0 col0" >Program_year</th>        <th class="col_heading level0 col1" >sum(Total_Amount_of_Payment_USDollars)</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002row0_col0" class="data row0 col0" >2017</td>
#                         <td id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002row0_col1" class="data row0 col1" >$2,814,070,049</td>
#             </tr>
#             <tr>
#                                 <td id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002row1_col0" class="data row1 col0" >2016</td>
#                         <td id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002row1_col1" class="data row1 col1" >$2,817,576,704</td>
#             </tr>
#             <tr>
#                                 <td id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002row2_col0" class="data row2 col0" >2015</td>
#                         <td id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002row2_col1" class="data row2 col1" >$2,687,032,307</td>
#             </tr>
#             <tr>
#                                 <td id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002row3_col0" class="data row3 col0" >2014</td>
#                         <td id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002row3_col1" class="data row3 col1" >$2,677,298,935</td>
#             </tr>
#             <tr>
#                                 <td id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002row4_col0" class="data row4 col0" >01/18/2019</td>
#                         <td id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002row4_col1" class="data row4 col1" >$18</td>
#             </tr>
#             <tr>
#                                 <td id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002row5_col0" class="data row5 col0" >None</td>
#                         <td id="T_d98ba154_8d36_11e9_9a95_0242ac1c0002row5_col1" class="data row5 col1" >$97,971</td>
#             </tr>
#     </tbody></table>

# %%
#Chart Spending by Month
ms_pdf = df.select(Func.date_format('Date_of_Payment','MM-yyyy').alias('Month'), 'Total_Amount_of_Payment_USDollars').groupby('Month').sum('Total_Amount_of_Payment_USDollars').toPandas().head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-e465695a38c0> in <module>()
# ----> 1 ms_pdf = df.select(Func.date_format('Date_of_Payment','MM-yyyy').alias('Month'), 'Total_Amount_of_Payment_USDollars').groupby('Month').sum('Total_Amount_of_Payment_USDollars').toPandas().head()
#
# /content/spark-2.4.3-bin-hadoop2.7/python/pyspark/sql/dataframe.py in toPandas(self)
#    2140
#    2141         # Below is toPandas without Arrow optimization.
# -> 2142         pdf = pd.DataFrame.from_records(self.collect(), columns=self.columns)
#    2143
#    2144         dtype = {}
#
# /content/spark-2.4.3-bin-hadoop2.7/python/pyspark/sql/dataframe.py in collect(self)
#     531         """
#     532         with SCCallSiteSync(self._sc) as css:
# --> 533             sock_info = self._jdf.collectToPython()
#     534         return list(_load_from_socket(sock_info, BatchedSerializer(PickleSerializer())))
#     535
#
# /content/spark-2.4.3-bin-hadoop2.7/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#    1257             answer, self.gateway_client, self.target_id, self.name)
#
# /content/spark-2.4.3-bin-hadoop2.7/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#     983         connection = self._get_connection()
#     984         try:
# --> 985             response = connection.send_command(command)
#     986             if binary:
#     987                 return response, self._create_connection_guard(connection)
#
# /content/spark-2.4.3-bin-hadoop2.7/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in send_command(self, command)
#    1150
#    1151         try:
# -> 1152             answer = smart_decode(self.stream.readline()[:-1])
#    1153             logger.debug("Answer received: {0}".format(answer))
#    1154             if answer.startswith(proto.RETURN_MESSAGE):
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Line Chart Spending By Month
import matplotlib.pyplot as plt
plt.style.use('ggplot')


#ms_pdf1 = ms_pdf.select('Month' >= Func.lit('01/2014'))   #.filter('Month' <= Func.lit('12/2017'))

#ms_pdf1 = ms_pdf[(ms_pdf['Month'] > '1') & (df['date'] <= '2000-6-10')]

ms_pdf1= ms_pdf[ms_pdf.Month[1-2014:12-2017]]
ms_pdf1

#plt.plot(ms_pdf1, 'Month', "sum(Total_Amount_of_Payment_USDollars")
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
#What is the Total Paymnents 2014 to 2016 by Recipient State?
df.groupby('Recipient_State').sum('Total_Amount_of_Payment_USDollars').orderBy('sum(Total_Amount_of_Payment_USDollars)', ascending=False).toPandas()\
.style.hide_index().set_properties(**{'background-color': 'lightgrey', 'color': 'Black','border-color': 'white', "text-align" : "right"})
# Out:
# <style  type="text/css" >
#     #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row0_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row0_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row1_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row1_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row2_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row2_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row3_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row3_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row4_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row4_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row5_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row5_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row6_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row6_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row7_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row7_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row8_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row8_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row9_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row9_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row10_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row10_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row11_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row11_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row12_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row12_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row13_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row13_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row14_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row14_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row15_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row15_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row16_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row16_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row17_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row17_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row18_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row18_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row19_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;
#         }    #T_38a0c8de_8d39_11e9_9a95_0242ac1c0002row19_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  right;

# %%
# What type of payments are made?
df.groupby('Nature_of_Payment_or_Transfer_of_Value').count().orderBy('count', ascending=False).toPandas()\
.style.hide_index().set_properties(**{'background-color': 'lightgrey', 'color': 'Black','border-color': 'white', "text-align" : "left"})
# Out:
# <style  type="text/css" >
#     #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row0_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row0_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row1_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row1_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row2_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row2_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row3_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row3_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row4_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row4_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row5_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row5_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row6_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row6_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row7_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row7_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row8_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row8_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row9_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row9_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row10_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row10_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row11_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row11_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row12_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row12_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row13_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row13_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row14_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row14_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row15_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row15_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row16_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row16_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row17_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row17_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row18_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_5bb05056_8d39_11e9_9a95_0242ac1c0002row18_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }</style><table id="T_5bb05056_8d39_11e9_9a95_0242ac1c0002" ><thead>    <tr>        <th class="col_heading level0 col0" >Nature_of_Payment_or_Transfer_of_Value</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_5bb05056_8d39_11e9_9a95_0242ac1c0002row0_col0" class="data row0 col0" >Food and Beverage</td>
#                         <td id="

# %%
#Display the Nature of the Payment by Dollars Amount in Groups, 0 to $1000, $1000 to $10,000, $10,000 to $100,000, $100,000 to $10,000,000, $10,0000+

splits = [-float("inf"), 0, 1000, 10000, 100000, 10000000, float("inf")]

#from pyspark.ml.feature import Bucketizer
#bucketizer = Bucketizer(splits = splits, inputCol="Total_Amount_of_Payment_USDollars", outputCol="Total Amount Payment Buckets")
#df = bucketizer.transform(df)


crosspdf = df.stat.crosstab('Nature_of_Payment_or_Transfer_of_Value', 'Total Amount Payment Buckets').toPandas()
crosspdf['TotalRow'] = crosspdf.sum(axis=1)
crosspdf.loc[-1] = crosspdf.sum(axis=0)
crosspdf.iloc[19,0] = "TotalCol"
crosspdf.style.hide_index().set_properties(**{'background-color': 'lightgrey', 'color': 'Black','border-color': 'white', "text-align" : "left"})
# Out:
# <style  type="text/css" >
#     #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row0_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row0_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row0_col2 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row0_col3 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row0_col4 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row0_col5 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row0_col6 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row0_col7 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row1_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row1_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row1_col2 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row1_col3 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row1_col4 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row1_col5 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row1_col6 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row1_col7 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row2_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row2_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row2_col2 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row2_col3 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row2_col4 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row2_col5 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row2_col6 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row2_col7 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row3_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row3_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row3_col2 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row3_col3 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row3_col4 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row3_col5 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row3_col6 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row3_col7 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row4_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row4_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row4_col2 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row4_col3 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row4_col4 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row4_col5 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row4_col6 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row4_col7 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_b0c0437a_8d3a_11e9_9a95_0242ac1c0002row5_col0 {

# %% [markdown]
# ####ANALYSIS
# The bulk of the payments between 2014 and 2017, some 38 million, are made are from 0 to 1000 Dollars on food and beverage category.

# %%
# What is the Physician Specialty?
df.groupby('Physician_Primary_Type').count().orderBy('count', ascending=False).toPandas()\
.style.hide_index().set_properties(**{'background-color': 'lightgrey', 'color': 'Black','border-color': 'white', "text-align" : "left"})
# Out:
# <style  type="text/css" >
#     #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row0_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row0_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row1_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row1_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row2_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row2_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row3_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row3_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row4_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row4_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row5_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row5_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row6_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row6_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row7_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row7_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row8_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row8_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row9_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row9_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row10_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row10_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row11_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row11_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }</style><table id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002" ><thead>    <tr>        <th class="col_heading level0 col0" >Physician_Primary_Type</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row0_col0" class="data row0 col0" >Medical Doctor</td>
#                         <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row0_col1" class="data row0 col1" >37639654</td>
#             </tr>
#             <tr>
#                                 <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row1_col0" class="data row1 col0" >Doctor of Osteopathy</td>
#                         <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row1_col1" class="data row1 col1" >3681225</td>
#             </tr>
#             <tr>
#                                 <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row2_col0" class="data row2 col0" >Doctor of Dentistry</td>
#                         <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row2_col1" class="data row2 col1" >1203755</td>
#             </tr>
#             <tr>
#                                 <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row3_col0" class="data row3 col0" >Doctor of Optometry</td>
#                         <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row3_col1" class="data row3 col1" >817511</td>
#             </tr>
#             <tr>
#                                 <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row4_col0" class="data row4 col0" >Doctor of Podiatric Medicine</td>
#                         <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row4_col1" class="data row4 col1" >468644</td>
#             </tr>
#             <tr>
#                                 <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row5_col0" class="data row5 col0" >None</td>
#                         <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row5_col1" class="data row5 col1" >174606</td>
#             </tr>
#             <tr>
#                                 <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row6_col0" class="data row6 col0" >Chiropractor</td>
#                         <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row6_col1" class="data row6 col1" >14450</td>
#             </tr>
#             <tr>
#                                 <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row7_col0" class="data row7 col0" >DC</td>
#                         <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row7_col1" class="data row7 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row8_col0" class="data row8 col0" >MO</td>
#                         <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row8_col1" class="data row8 col1" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row9_col0" class="data row9 col0" >Dental Providers|Dentist</td>
#                         <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row9_col1" class="data row9 col1" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_c3ff32fc_8d3a_11e9_9a95_0242ac1c0002row10_col0" class="data row10 col0" >Podiatric Med

# %%
# What is the Physician Specialty?
df.groupby('Physician_Specialty').count().orderBy('count', ascending=False).toPandas().head(10)\
.style.hide_index().set_properties(**{'background-color': 'lightgrey', 'color': 'Black','border-color': 'white', "text-align" : "left"})
# Out:
# <style  type="text/css" >
#     #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row0_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row0_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row1_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row1_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row2_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row2_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row3_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row3_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row4_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row4_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row5_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row5_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row6_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row6_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row7_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row7_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row8_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row8_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row9_col0 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }    #T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row9_col1 {
#             background-color:  lightgrey;
#             color:  Black;
#             border-color:  white;
#             text-align:  left;
#         }</style><table id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002" ><thead>    <tr>        <th class="col_heading level0 col0" >Physician_Specialty</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row0_col0" class="data row0 col0" >Allopathic & Osteopathic Physicians|Family Medicine</td>
#                         <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row0_col1" class="data row0 col1" >7536387</td>
#             </tr>
#             <tr>
#                                 <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row1_col0" class="data row1 col0" >Allopathic & Osteopathic Physicians|Internal Medicine</td>
#                         <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row1_col1" class="data row1 col1" >6742717</td>
#             </tr>
#             <tr>
#                                 <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row2_col0" class="data row2 col0" >Allopathic & Osteopathic Physicians|Internal Medicine|Cardiovascular Disease</td>
#                         <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row2_col1" class="data row2 col1" >2581140</td>
#             </tr>
#             <tr>
#                                 <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row3_col0" class="data row3 col0" >Allopathic & Osteopathic Physicians|Psychiatry & Neurology|Neurology</td>
#                         <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row3_col1" class="data row3 col1" >1753926</td>
#             </tr>
#             <tr>
#                                 <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row4_col0" class="data row4 col0" >Allopathic & Osteopathic Physicians|Internal Medicine|Gastroenterology</td>
#                         <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row4_col1" class="data row4 col1" >1414703</td>
#             </tr>
#             <tr>
#                                 <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row5_col0" class="data row5 col0" >Allopathic & Osteopathic Physicians|Psychiatry & Neurology|Psychiatry</td>
#                         <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row5_col1" class="data row5 col1" >1412532</td>
#             </tr>
#             <tr>
#                                 <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row6_col0" class="data row6 col0" >Allopathic & Osteopathic Physicians|Internal Medicine|Endocrinology, Diabetes & Metabolism</td>
#                         <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row6_col1" class="data row6 col1" >1237311</td>
#             </tr>
#             <tr>
#                                 <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row7_col0" class="data row7 col0" >Allopathic & Osteopathic Physicians|Internal Medicine|Hematology & Oncology</td>
#                         <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row7_col1" class="data row7 col1" >1169231</td>
#             </tr>
#             <tr>
#                                 <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row8_col0" class="data row8 col0" >Allopathic & Osteopathic Physicians|Dermatology</td>
#                         <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row8_col1" class="data row8 col1" >1089112</td>
#             </tr>
#             <tr>
#                                 <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row9_col0" class="data row9 col0" >Allopathic & Osteopathic Physicians|Obstetrics & Gynecology</td>
#                         <td id="T_fb28566e_8d3a_11e9_9a95_0242ac1c0002row9_col1" class="data row9 col1" >1010884</td>
#             </tr>
#     </tbody></table>
